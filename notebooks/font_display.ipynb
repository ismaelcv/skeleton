# %% [markdown]
# ### Import Libraries

# %%
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# ### Display the fonts

# %%
fonts = [f.name for f in matplotlib.font_manager.fontManager.ttflist]

plt.figure(figsize=(10,10))
 
for i,font in enumerate(fonts): 

    plt.text( 1 , i*0.8, font, fontdict={'size':22, 'alpha':0.8, "fontfamily":font}, color='black', ha= 'left',label='_nolegend_');

plt.ylim(0,10)
plt.xlim(0,10)


# Remove contour
plt.gca().spines["left"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["bottom"].set_visible(False)
plt.gca().spines["top"].set_visible(False)
plt.gca().xaxis.set_visible(False)
plt.gca().yaxis.set_visible(False)
# Out:
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 83 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 84 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 73 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 88 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 78 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 111 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 110 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 85 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 105 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 99 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 100 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 101 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 122 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 70 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 117 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 114 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 121 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 79 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 68 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 106 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 97 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 86 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 115 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 118 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 87 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 98 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 103 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 83 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 84 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 73 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 88 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 78 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 111 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 110 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 85 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 105 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 99 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 100 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 101 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 122 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 70 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 117 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 114 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 121 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 119 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 79 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 68 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 106 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 97 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 86 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 115 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 102 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 118 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 87 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 98 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ismael/repos/skeleton/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 103 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
fonts
# Out:
# ['DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'cmex10',
#  'cmtt10',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'cmr10',
#  'cmsy10',
#  'cmss10',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'cmmi10',
#  'DejaVu Sans Display',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'cmb10',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'Verdana',
#  'Roboto Mono Thin for Powerline',
#  'Space Mono for Powerline',
#  'IBM 3270 Narrow',
#  'Meslo LG L for Powerline',
#  'Georgia',
#  'Cousine for Powerline',
#  'Trebuchet MS',
#  'Meslo LG L for Powerline',
#  'Source Code Pro for Powerline',
#  'Meslo LG M for Powerline',
#  'Arial',
#  'Andale Mono',
#  'Arial Black',
#  'DejaVu Sans',
#  'Liberation Mono',
#  'Meslo LG S DZ for Powerline',
#  'Arial',
#  'Courier New',
#  'Georgia',
#  'Arial Black',
#  'Source Code Pro for Powerline',
#  'Meslo LG L DZ for Powerline',
#  'DejaVu Sans',
#  'ProFont for Powerline',
#  'Source Code Pro for Powerline',
#  'Roboto Mono for Powerline',
#  'Go Mono for Powerline',
#  'Source Code Pro for Powerline',
#  'Trebuchet MS',
#  'Fira Mono for Powerline',
#  'Webdings',
#  'Arial',
#  'Arial',
#  'Ubuntu Mono derivative Powerline',
#  'Hack',
#  'Roboto Mono for Powerline',
#  'Hack',
#  'Meslo LG M for Powerline',
#  'IBM 3270 Semi-Narrow',
#  'Meslo LG S DZ for Powerline',
#  'Arimo for Powerline',
#  'Space Mono',
#  'Courier New',
#  'Source Code Pro for Powerline',
#  'Meslo LG M DZ for Powerline',
#  'Source Code Pro for Powerline',
#  'DejaVu Serif',
#  'monofur for Powerline',
#  'Verdana',
#  'Meslo LG M DZ for Powerline',
#  'Times New Roman',
#  'Courier New',
#  'Meslo LG S DZ for Powerline',
#  'Courier New',
#  'Liberation Mono for Powerline',
#  'Symbol Neu for Powerline',
#  'Roboto Mono Light for Powerline',
#  'NovaMono for Powerline',
#  'Comic Sans MS',
#  'Trebuchet MS',
#  'Liberation Sans',
#  'Georgia',
#  'Trebuchet MS',
#  'Georgia',
#  'Arimo for Powerline',
#  'Times New Roman',
#  'Roboto Mono for Powerline',
#  'Source Code Pro for Powerline',
#  'ProFont for Powerline',
#  'Arial',
#  'Tinos for Powerline',
#  'Verdana',
#  'Liberation Sans',
#  'Meslo LG L for Powerline',
#  'Source Code Pro for Powerline',
#  'Courier New',
#  'Times New Roman',
#  'Liberation Mono',
#  'Roboto Mono for Powerline',
#  'Georgia',
#  'Meslo LG L DZ for Powerline',
#  'Cousine for Powerline',
#  'Comic Sans MS',
#  'Cousine for Powerline',
#  'Meslo LG M DZ for Powerline',
#  'Fira Mono for Powerline',
#  'Source Code Pro for Powerline',
#  'Comic Sans MS',
#  'monofur for Powerline',
#  'Meslo LG L for Powerline',
#  'Meslo LG S for Powerline',
#  'Space Mono for Powerline',
#  'Liberation Mono',
#  'Droid Sans Mono for Powerline',
#  'Arial',
#  'Andale Mono',
#  'IBM 3270',
#  'Ubuntu Mono derivative Powerline',
#  'Inconsolata for Powerline',
#  'DejaVu Serif',
#  'Trebuchet MS',
#  'Liberation Mono',
#  'Droid Sans Mono Dotted for Powerline',
#  'Georgia',
#  'Liberation Sans Narrow',
#  'Courier New',
#  'Space Mono',
#  'Inconsolata-dz for Powerline',
#  'Arial',
#  'Times New Roman',
#  'DejaVu Sans Mono for Powerline',
#  'Source Code Pro for Powerline',
#  'Georgia',
#  'Source Code Pro for Powerline',
#  'Inconsolata for Powerline',
#  'Meslo LG L DZ for Powerline',
#  'Liberation Mono for Powerline',
#  'Droid Sans Mono Slashed for Powerline',
#  'Noto Mono for Powerline',
#  'Verdana',
#  'Meslo LG S DZ for Powerline',
#  'Arial',
#  'Verdana',
#  'Arimo for Powerline',
#  'Ubuntu Mono derivative Powerline',
#  'Source Code Pro for Powerline',
#  'Liberation Serif',
#  'Impact',
#  'Times New Roman',
#  'Liberation Serif',
#  'Comic Sans MS',
#  'Anonymous Pro for Powerline',
#  'Arimo for Powerline',
#  'Meslo LG S for Powerline',
#  'Space Mono for Powerline',
#  'Courier New',
#  'Times New Roman',
#  'Roboto Mono Medium for Powerline',
#  'Liberation Mono for Powerline',
#  'monofur for Powerline',
#  'DejaVu Sans Mono for Powerline',
#  'Meslo LG S for Powerline',
#  'Liberation Sans',
#  'DejaVu Sans Mono for Powerline',
#  'Courier New',
#  'Trebuchet MS',
#  'Anonymous Pro for Powerline',
#  'Roboto Mono Light for Powerline',
#  'Roboto Mono Thin for Powerline',
#  'Inconsolata-g for Powerline',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Mono for Powerline',
#  'Fira Mono for Powerline',
#  'Trebuchet MS',
#  'Source Code Pro for Powerline',
#  'DejaVu Sans Mono for Powerline',
#  'Hack',
#  'Ubuntu Mono derivative Powerline',
#  'Go Mono for Powerline',
#  'DejaVu Sans Mono',
#  'Liberation Sans',
#  'Verdana',
#  'Meslo LG M DZ for Powerline',
#  'Source Code Pro for Powerline',
#  'Space Mono',
#  'Georgia',
#  'Hack',
#  'Liberation Serif',
#  'Tinos for Powerline',
#  'Roboto Mono Medium for Powerline',
#  'Anonymous Pro for Powerline',
#  'Meslo LG M for Powerline',
#  'Webdings',
#  'Verdana',
#  'Meslo LG S for Powerline',
#  'Times New Roman',
#  'Space Mono for Powerline',
#  'Times New Roman',
#  'Liberation Serif',
#  'Trebuchet MS',
#  'Liberation Sans Narrow',
#  'DejaVu Sans Mono',
#  'Go Mono for Powerline',
#  'Anonymous Pro for Powerline',
#  'Impact',
#  'Tinos for Powerline',
#  'Meslo LG L DZ for Powerline',
#  'Tinos for Powerline',
#  'Space Mono',
#  'Verdana',
#  'Cousine for Powerline',
#  'Meslo LG M for Powerline',
#  'Go Mono for Powerline']
